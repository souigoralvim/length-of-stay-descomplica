# %% [markdown]
# # Decision tree model
# ## 1. Importing libraries and loading data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (accuracy_score, classification_report, confusion_matrix)

# %%
data = pd.read_csv(Path.cwd() / ".." / "data" / "processed" / "healthcare_dataset_processed.csv")
data_without_insurance = pd.read_csv(Path.cwd() / ".." / "data" / "processed" / "processed_dataset_without_insurance.csv")

# %% [markdown]
# ## 2. Split data by train and test
#
# ### 2.1 Variables

# %%
y = data['LOS Category']
X1 = data.drop(columns=['LOS Category'])
X2 = data_without_insurance.drop(columns=['LOS Category'])

# %% [markdown]
# ### 2.2 Splitting

# %%
train_X1, test_X1, train_y, test_y = train_test_split(X1, y, test_size=0.2, random_state=42, stratify=y) # Stratify to maintain class distribution in train and test sets
train_X2, test_X2, train_y, test_y = train_test_split(X2, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ## 3. Fit model
#
# Fit data with insurance provider

# %%
decision_tree_model = DecisionTreeClassifier(random_state=42)
decision_tree_model.fit(train_X1, train_y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# Fit data without insurance provider

# %%
decision_tree_model_without_insurance = DecisionTreeClassifier(random_state=42)
decision_tree_model_without_insurance.fit(train_X2, train_y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# ## 4. Predict
#
# Predict data with insurance

# %%
predictions_with_insurance = decision_tree_model.predict(test_X1)

# %% [markdown]
# Predict Data without insurance provider

# %%
predictions_without_insurance = decision_tree_model_without_insurance.predict(test_X2)

# %% [markdown]
# ## 5. Metrics
#
# ### 5.1 Accuracy
# Accuracy indicates how many classifications were correct from all classifications. The general formula is:
#
# $Accuracy = \frac{TP + TN}{TP + TN + FP + FN}$
#
# Where:
# - TP = True Positive
# - TN = True Negative
# - FP = False Positive
# - FN = False Negative

# %%
accuracy_with_insurance = accuracy_score(test_y, predictions_with_insurance)
accuracy_without_insurance = accuracy_score(test_y, predictions_without_insurance)
print("Accuracy with insurance:", accuracy_with_insurance) 
print("Accuracy without insurance:", accuracy_without_insurance)
# Out:
# Accuracy with insurance: 0.7516216216216216
# Accuracy without insurance: 0.7649549549549549

# %% [markdown]
# Accuracy with insurance: 0.7516216216216216
#
# Accuracy without insurance: 0.7649549549549549

# %% [markdown]
# ### 5.2 Classification Report
#
# Classification report brings the following metrics:
#
# $Precision: \frac{TP}{TP+FP}$
#
# $Recall: \frac{TP}{TP+FN}$
#
# $F1-Score: 2 \times \frac{Precision \times Recall}{Precision + Recall}$ (The F1-Score is the harmonic mean between Precision and Recall)

# %%
classification_report_with_insurance = classification_report(test_y, predictions_with_insurance)
classification_report_without_insurance = classification_report(test_y, predictions_without_insurance)
print("Classification Report with insurance:")
print(classification_report_with_insurance)
print("Classification Report without insurance:")
print(classification_report_without_insurance)
# Out:
# Classification Report with insurance:
#               precision    recall  f1-score   support
#
#    Long Stay       0.94      0.94      0.94      3907
#  Medium Stay       0.53      0.57      0.55      2977
#   Short Stay       0.74      0.71      0.72      4216
#
#     accuracy                           0.75     11100
#    macro avg       0.74      0.74      0.74     11100
# weighted avg       0.76      0.75      0.75     11100
#
# Classification Report without insurance:
#               precision    recall  f1-score   support
#
#    Long Stay       0.94      0.96      0.95      3907
#  Medium Stay       0.56      0.60      0.58      2977
#   Short Stay       0.75      0.70      0.73      4216
#
#     accuracy                           0.76     11100
#    macro avg       0.75      0.75      0.75     11100
# weighted avg       0.77      0.76      0.77     11100

# %% [markdown]
# ### 5.3 Confusion Matrix

# %%
confusion_matrix_with_insurance = confusion_matrix(test_y, predictions_with_insurance)
confusion_matrix_without_insurance = confusion_matrix(test_y, predictions_without_insurance)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# With Insurance Provider
sns.heatmap(
    confusion_matrix_with_insurance,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=decision_tree_model.classes_,
    yticklabels=decision_tree_model.classes_,
    ax=axes[0]
)

axes[0].set_title('With Insurance Provider')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# Without Insurance Provider
sns.heatmap(
    confusion_matrix_without_insurance,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=decision_tree_model.classes_,
    yticklabels=decision_tree_model.classes_,
    ax=axes[1]
)

axes[1].set_title('Without Insurance Provider')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Export results
#
# ### 6.1 Classification report to dictionary

# %%
classification_report_with_insurance = classification_report(test_y, predictions_with_insurance, output_dict=True)
classification_report_without_insurance = classification_report(test_y, predictions_without_insurance, output_dict=True)

# %% [markdown]
# ### 6.2 Create results DataFrame

# %%
results = pd.DataFrame({
    'Model': ['Decision Tree', 'Decision Tree'],
    'Insurance Provider': ['Y', 'N'],
    'Accuracy': [accuracy_with_insurance, accuracy_without_insurance],
    'Precision': [classification_report_with_insurance['weighted avg']['precision'], classification_report_without_insurance['weighted avg']['precision']],
    'Recall': [classification_report_with_insurance['weighted avg']['recall'], classification_report_without_insurance['weighted avg']['recall']],
    'F1-Score': [classification_report_with_insurance['weighted avg']['f1-score'], classification_report_without_insurance['weighted avg']['f1-score']]
})

print(results)
# Out:
#            Model Insurance Provider  Accuracy  Precision    Recall  F1-Score
# 0  Decision Tree                  Y  0.751622   0.755418  0.751622  0.753245
# 1  Decision Tree                  N  0.764955   0.767574  0.764955  0.765612

# %% [markdown]
# ### 6.3 Export Dataframe

# %%
results.to_csv(Path.cwd() / ".." / "data" / "results" / "results.csv", index=False)

# %% [markdown]
# ### 6.4 Export confusion matrix plots

# %%
output_dir = Path.cwd() / ".." / "data" / "results"

# Individual: With Insurance
fig1, ax1 = plt.subplots(figsize=(7, 6))
sns.heatmap(
    confusion_matrix_with_insurance,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=decision_tree_model.classes_,
    yticklabels=decision_tree_model.classes_,
    ax=ax1
)
ax1.set_title('Confusion Matrix - With Insurance Provider')
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
fig1.savefig(output_dir / "confusion_matrix_with_insurance.png", dpi=300, bbox_inches='tight')
plt.close(fig1)

# Individual: Without Insurance
fig2, ax2 = plt.subplots(figsize=(7, 6))
sns.heatmap(
    confusion_matrix_without_insurance,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=decision_tree_model.classes_,
    yticklabels=decision_tree_model.classes_,
    ax=ax2
)
ax2.set_title('Confusion Matrix - Without Insurance Provider')
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Actual')
fig2.savefig(output_dir / "confusion_matrix_without_insurance.png", dpi=300, bbox_inches='tight')
plt.close(fig2)

# Combined side-by-side
fig_comb, axes_comb = plt.subplots(1, 2, figsize=(14, 6))
sns.heatmap(
    confusion_matrix_with_insurance,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=decision_tree_model.classes_,
    yticklabels=decision_tree_model.classes_,
    ax=axes_comb[0]
)
axes_comb[0].set_title('With Insurance Provider')
axes_comb[0].set_xlabel('Predicted')
axes_comb[0].set_ylabel('Actual')

sns.heatmap(
    confusion_matrix_without_insurance,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=decision_tree_model.classes_,
    yticklabels=decision_tree_model.classes_,
    ax=axes_comb[1]
)
axes_comb[1].set_title('Without Insurance Provider')
axes_comb[1].set_xlabel('Predicted')
axes_comb[1].set_ylabel('Actual')

plt.tight_layout()
fig_comb.savefig(output_dir / "confusion_matrices_comparison.png", dpi=300, bbox_inches='tight')
plt.close(fig_comb)
